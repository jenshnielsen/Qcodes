# %%
def test_foo_bar():
    assert "foobar" == "foobar"

# %%
source = """
def test_foo_bar():
    assert "foobar" == "foobar"
"""

# %%
import libcst as cst
from libcst import Annotation, Name

# %%
source_tree = cst.parse_module(source)

# %%
from typing import Optional

# %%
class TypingTransformer(cst.CSTTransformer):
    def __init__(self):
        # stack for storing the canonical name of the current function
        self.stack: list[str] = []
        # store the annotations

    def visit_ClassDef(self, node: cst.ClassDef) -> Optional[bool]:
        self.stack.append(node.name.value)
        print(node.name.value)

    def leave_ClassDef(
        self, original_node: cst.ClassDef, updated_node: cst.ClassDef
    ) -> cst.CSTNode:
        self.stack.pop()
        return updated_node

    def visit_FunctionDef(self, node: cst.FunctionDef) -> Optional[bool]:
        self.stack.append(node.name.value)
        return (
            False
        )  # we are not changing the code

    def leave_FunctionDef(
        self, original_node: cst.FunctionDef, updated_node: cst.FunctionDef
    ) -> cst.CSTNode:
        key = self.stack[-1]
        print(key)
        
        self.stack.pop()
        if key.startswith("test") and original_node.returns is None:
            return updated_node.with_changes(returns=Annotation(annotation=Name(
                value='None',
                lpar=[],
                rpar=[],
            )))
        else:
            return updated_node

# %%
transformer = TypingTransformer()

# %%
modified_tree = source_tree.visit(transformer)
# Out:
# test_foo_bar

# %%
print(modified_tree.code)
# Out:
# def test_foo_bar() -> None:
#     assert "foobar" == "foobar"

# %%
print(source)
# Out:
# def test_foo_bar():
#     assert "foobar" == "foobar"

# %%
with open("qcodes/tests/dataset/test_converters.py") as f:
    source = f.read()

# %%
source_tree = cst.parse_module(source)

# %%
modified_tree = source_tree.visit(transformer)
# Out:
# test_convert_v0_to_newer
# test_convert_v1
# test_convert_v2
# _assert_dicts_are_related_as_expected
# test_construct_current_rundescriber_from_v0
# test_construct_current_rundescriber_from_v1
# test_construct_current_rundescriber_from_v2
# test_construct_current_rundescriber_from_v3
# test_construct_current_rundescriber_from_fake_v4

# %%
with open("qcodes/tests/dataset/test_converters.py", "w") as f:
    f.write(modified_tree.code)

# %%
from pathlib import Path

# %%
for mypath in Path('./qcodes/tests').glob("**/*.py"):
    with open(mypath) as f:
        source = f.read()
    source_tree = cst.parse_module(source)
    modified_tree = source_tree.visit(transformer)
    with open(mypath, "w") as f:
        f.write(modified_tree.code)
# Out:
# strip_qc
# retry_until_does_not_throw
# profile
# error_caused_by
# skip_if_no_fixtures
# DumyPar
# __init__
# __str__
# set
# default_config
# reset_config_on_exit
# compare_dictionaries
# pytest_configure
# pytest_runtest_setup
# disable_telemetry
# default_config
# reset_config_on_exit
# disable_config_subscriber
# _make_empty_temp_db
# _make_experiment
# _make_dataset
# _make_standalone_parameters_dataset
# _make_set_default_station_to_none
# dataset_with_outliers_generator
# DriverTestCase
# setUpClass
# test_instruments
# test_instrument
# DummyBase
# get_idn
# MockParabola
# __init__
# _measure_parabola
# _measure_skewed_parabola
# MockMetaParabola
# __init__
# _get_parabola
# _get_skew_parabola
# DummyInstrument
# __init__
# DummyFailingInstrument
# __init__
# DummyAttrInstrument
# __init__
# DmmExponentialParameter
# __init__
# get_raw
# _exponential_decay
# DmmGaussParameter
# __init__
# get_raw
# _gauss_model
# DummyInstrumentWithMeasurement
# __init__
# DummyChannel
# __init__
# turn_on
# DummyChannelInstrument
# __init__
# MultiGetter
# __init__
# get_raw
# MultiSetPointParam
# __init__
# get_raw
# Multi2DSetPointParam
# __init__
# get_raw
# Multi2DSetPointParam2Sizes
# __init__
# get_raw
# MultiScalarParam
# __init__
# get_raw
# ArraySetPointParam
# __init__
# get_raw
# ComplexArraySetPointParam
# __init__
# get_raw
# GeneratedSetPoints
# __init__
# get_raw
# DummyParameterWithSetpoints1D
# get_raw
# DummyParameterWithSetpoints2D
# get_raw
# DummyParameterWithSetpointsComplex
# get_raw
# setpoint_generator
# SnapShotTestInstrument
# __init__
# _getter
# snapshot_base
# MockField
# __init__
# get_field
# set_field
# _field_ramp_fcn
# _field_ramp
# MockLockin
# __init__
# MockDACChannel
# __init__
# channel_number
# MockDAC
# __init__
# MockCustomChannel
# __init__
# ExampleBaseVoltageSource
# __init__
# VoltageSource
# __init__
# VoltageSourceNotImplemented
# VoltageSourceBadUnit
# __init__
# VoltageSourceInitException
# __init__
# VoltageChannelBase
# __init__
# VoltageChannel
# __init__
# VoltageAbstractChannelSource
# __init__
# VoltageChannelSource
# __init__
# VoltageAbstractChannelListSource
# __init__
# VoltageChannelListSource
# __init__
# _driver
# test_sanity
# test_not_implemented_error
# test_unit_value_error
# test_unit_value_error_does_not_register_instrument
# test_exception_in_init
# test_abstract_channel_raises
# test_non_abstract_channel_does_not_raises
# test_abstract_channellist_raises
# test_non_abstract_channellist_does_not_raises
# MockBackendBase
# __init__
# send
# MockBackend
# __init__
# _add_channel
# SimpleTestChannel
# _discover_from_instrument
# _get_new_instance_kwargs
# __init__
# _create
# _remove
# DummyInstrument
# __init__
# write_raw
# ask_raw
# dummy_instrument
# test_sanity
# test_channels_list
# test_with_kwargs
# _make_dci
# _make_dci_with_list
# _make_empty_instrument
# EmptyChannel
# test_instrument_channel_label
# test_channels_call_function
# test_channels_get
# test_channel_access_is_identical
# test_invalid_channel_type_raises
# test_invalid_multichan_type_raises
# test_wrong_chan_type_raises
# test_append_channel
# test_append_channel_wrong_type_raises
# test_extend_channels_from_generator
# test_extend_channels_from_tuple
# test_extend_wrong_type_raises
# test_extend_locked_list_raises
# test_extend_then_remove
# test_insert_channel
# test_insert_channel_wrong_type_raises
# test_add_none_channel_tuple_to_channel_tuple_raises
# test_add_channel_tuples_of_different_types_raises
# test_add_channel_tuples_from_different_parents
# test_chan_tuple_repr
# test_chan_list_repr
# test_channel_tuple_get_validator
# test_channel_list_get_validator
# test_channel_list_get_validator_not_locked_raised
# test_channel_tuple_index
# test_channel_tuple_snapshot
# test_channel_tuple_snapshot_enabled
# test_channel_tuple_dir
# test_clear_channels
# test_clear_locked_channels
# test_remove_channel
# test_remove_locked_channel
# test_channel_list_lock_twice
# test_remove_tupled_channel
# test_combine_channels
# test_access_channels_by_slice
# test_access_channels_by_tuple
# test_access_channels_by_name_empty_raises
# test_delete_from_channel_list
# test_set_element_by_int
# test_set_element_by_slice
# test_set_element_locked_raises
# test_access_channels_by_name
# test_channels_contain
# test_channels_reverse
# test_channels_count
# test_channels_is_sequence
# test_names
# test_root_instrument
# test_get_attr_on_empty_channellist_works_as_expected
# test_channel_tuple_call_method_basic_test
# test_channel_tuple_call_method_called_as_expected
# _verify_multiparam_data
# _verify_array_data
# CustomError
# test_bad_calls
# test_no_cmd
# test_cmd_str
# test_cmd_function_1
# test_cmd_function_2
# side_effect
# path_to_config_file_on_disk
# _make_config
# _make_mock_config
# test_missing_config_file
# test_default_config_files
# test_bad_config_files
# test_user_schema
# test_bad_user_schema
# test_update_user_config
# test_update_and_validate_user_config
# test_update_from_path
# test_repr
# test_add_and_describe
# test_assert_deprecated_raises
# test_assert_deprecated_does_not_raise_wrong_msg
# test_assert_deprecated_does_not_raise_wrong_type
# test_assert_not_deprecated_raises
# test_assert_not_deprecated_does_not_raise
# test_similar_output
# test_deprecated_context_manager
# C
# __init__
# method
# static_method
# class_method
# prop
# prop
# test_init_uninhibited
# test_init_raises
# test_method_uninhibited
# test_method_raises
# test_static_method_uninhibited
# test_static_method_raises
# test_class_method_uninhibited
# test_class_method_raises
# test_property_uninhibited
# test_property_raises
# test_setter_uninhibited
# test_setter_raises
# test_spherical_properties
# test_cylindrical_properties
# test_triangle_inequality
# test_homogeneous_roundtrip
# test_json_dump
# test_all_attributes_are_floats
# test_get_qcodes_version
# test_is_qcodes_installed_editably
# test_get_all_installed_package_versions
# test_convert_legacy_version_to_supported_version
# _dummy_dac
# _dummy_channel_instr
# _dummy_parabola
# _close_before_and_after
# test_validate_function
# test_check_instances
# test_instrument_fail
# test_instrument_on_invalid_identifier
# test_instrument_warns_on_hyphen_in_name
# test_instrument_allows_channel_name_starting_with_number
# test_instrument_channel_name_raise_on_invalid
# test_instrument_retry_with_same_name
# test_attr_access
# test_attr_access_channels
# test_get_idn
# test_repr
# test_add_remove_f_p
# test_instances
# test_is_valid
# test_snapshot_value
# test_meta_instrument
# test_find
# test_find_same_name_but_different_class
# test_create
# test_other_exception
# test_recreate
# test_instrument_metadata
# test_instrumentbase_metadata
# test_instrument_label
# test_snapshot_and_meta_attrs
# TestSnapshotType
# __init__
# snapshot_base
# TestInstrument
# __init__
# test_attribute
# test_snapshot_and_meta_attrs2
# _create_tab
# test_snapshot_browser
# test_full_widget_on_empty_db
# test_full_widget_on_empty_experiment
# test_full_widget_on_empty_dataset
# test_full_widget_on_one_dataset
# test_button_to_text
# test_snapshot_button
# test_plot_button
# test_get_experiment_button
# test_get_parameters
# test_editable_metadata
# test_experiments_widget
# test_experiments_widget_sorting
# remove_root_handlers
# awg5208
# model372
# AMI430_3D
# test_get_log_file_name
# test_start_logger
# test_start_logger_twice
# test_set_level_without_starting_raises
# test_handler_level
# test_filter_instrument
# test_filter_without_started_logger_raises
# test_capture_dataframe
# test_channels
# test_channels_nomessages
# test_instrument_connect_message
# test_installation_info_logging
# HasSnapshotBase
# snapshot_base
# HasSnapshot
# snapshot
# test_load
# test_init
# test_snapshot
# test_dataset_diff
# test_station_diff
# test_instrument_diff
# _make_inst_and_monitor
# _make_channel_instr
# _make_channel_instr_monitor
# test_setup_teardown
# test_monitor_replace
# test_double_join
# test_connection
# test_instrument_update
# test_monitor_root_instr
# dataset_with_data_outside_iqr_high_outlier
# dataset_with_data_outside_iqr_low_outlier
# dataset_with_outliers
# test_extend
# test_defaults
# test_snapshot_skip_params_update
# test_snapshot_exclude_params
# use_default_config
# set_default_station_to_none_automatically
# close_all_instruments
# treat_validation_warning_as_error
# test_station
# test_station_getitem
# test_station_delegated_attributes
# test_add_component
# test_add_component_without_specifying_name
# test_add_component_with_no_name
# test_remove_component
# test_close_all_registered_instruments
# test_snapshot
# test_station_after_instrument_is_closed
# test_update_config_schema
# config_file_context
# config_files_context
# _make_example_station_config
# test_dynamic_reload_of_file
# station_from_config_str
# station_config_has_been_loaded
# _make_example_station
# test_station_config_path_resolution
# test_station_configuration_is_a_component_of_station
# test_station_config_can_be_loaded_from_snapshot
# simple_mock_station
# test_simple_mock_config
# test_simple_mock_load_mock
# test_simple_mock_load_instrument
# test_enable_force_reconnect
# test_revive_instance
# test_init_parameters
# test_name_init_kwarg
# test_name_specified_in_init_in_yaml_is_used
# InstrumentWithNameAsNotFirstArgument
# __init__
# test_able_to_load_instrument_with_name_argument_not_being_the_first
# test_setup_alias_parameters
# test_setup_delegate_parameters
# test_channel_instrument
# test_setting_channel_parameter
# test_monitor_not_loaded_by_default
# test_monitor_loaded_if_specified
# test_monitor_loaded_by_default_if_in_config
# test_monitor_not_loaded_if_specified
# test_deprecated_driver_keyword
# test_deprecated_limits_keyword_as_string
# test_config_validation_failure
# test_config_validation_failure_on_file
# test_config_validation_comprehensive_config
# test_load_all_instruments_raises_on_both_only_names_and_only_types_passed
# test_load_all_instruments_no_args
# test_load_all_instruments_only_types
# test_load_all_instruments_only_names
# test_load_all_instruments_without_config_raises
# test_station_config_created_with_multiple_config_files
# _make_c0
# _make_c1
# _make_c2
# test_errors
# test_valid
# test_base
# test_snapshot
# test_repr
# test_error_caused_by_simple
# test_error_caused_by_try_catch
# test_error_caused_by_3_level
# ParameterWithThreadKnowledge
# __init__
# get_raw
# _dummy_dac1
# _dummy_dac2
# test_call_params_threaded
# test_thread_pool_params_caller
# MockVisa
# __init__
# _open_resource
# MockVisaHandle
# __init__
# clear
# close
# write
# ask
# query
# set_visa_attribute
# __del__
# _make_mock_visa
# test_ask_write_local
# test_visa_backend
# test_visa_instr_metadata
# test_both_visahandle_and_pyvisa_sim_file_raises
# test_load_pyvisa_sim_file_implict_module
# test_load_pyvisa_sim_file_explicit_module
# test_load_pyvisa_sim_file_invalid_file_raises
# test_load_pyvisa_sim_file_invalid_module_raises
# _make_non_created_db
# empty_temp_db_connection
# two_empty_temp_db_connections
# temporarily_copied_DB
# _make_scalar_dataset
# _make_scalar_datasets_parameterized
# scalar_dataset_with_nulls
# array_dataset
# array_dataset_with_nulls
# multi_dataset
# different_setpoint_dataset
# array_in_scalar_dataset
# varlen_array_in_scalar_dataset
# array_in_scalar_dataset_unrolled
# array_in_str_dataset
# some_paramspecbases
# some_paramspecs
# some_interdeps
# _make_dac
# _make_dac_3d
# _make_dac_with_metadata
# _make_dmm
# channel_array_instrument
# complex_num_instrument
# SpectrumAnalyzer
# meas_with_registered_param
# meas_with_registered_param_2d
# meas_with_registered_param_3d
# _make_meas_with_registered_param_complex
# _make_dummy_instrument
# ArrayshapedParam
# __init__
# get_raw
# verify_data_dict
# verify_data_dict_for_single_param
# verify_dataframe_for_single_param
# test_foreground_after_background_raises
# test_background_after_foreground_raises
# test_background_twice
# test_foreground_twice
# test_foreground_after_background_non_concurrent
# test_convert_v0_to_newer
# test_convert_v1
# test_convert_v2
# _assert_dicts_are_related_as_expected
# test_construct_current_rundescriber_from_v0
# test_construct_current_rundescriber_from_v1
# test_construct_current_rundescriber_from_v2
# test_construct_current_rundescriber_from_v3
# test_construct_current_rundescriber_from_fake_v4
# location_and_station_set_to
# test_connect_upgrades_user_version
# test_tables_exist
# test_initialise_database_at_for_nonexisting_db
# test_initialise_database_at_for_nonexisting_db_pathlib_path
# test_initialise_database_at_for_existing_db
# test_perform_actual_upgrade_0_to_1
# test_perform_actual_upgrade_1_to_2
# test_perform_actual_upgrade_2_to_3_empty
# test_perform_actual_upgrade_2_to_3_empty_runs
# test_perform_actual_upgrade_2_to_3_some_runs
# test_perform_upgrade_v2_v3_to_v4_fixes
# test_perform_upgrade_v3_to_v4
# test_update_existing_guids
# _assert_loc_station
# test_perform_actual_upgrade_4_to_5
# test_perform_actual_upgrade_5_to_6
# test_perform_upgrade_6_7
# test_perform_actual_upgrade_6_to_7
# test_perform_actual_upgrade_6_to_newest_add_new_data
# test_perform_actual_upgrade_7_to_8
# test_cannot_connect_to_newer_db
# test_latest_available_version
# test_getting_db_version
# test_perform_actual_upgrade_8_to_9
# raise_if_file_changed
# _make_inst
# test_missing_runs_raises
# test_basic_extraction
# test_real_dataset_1d
# test_real_dataset_1d_pathlib_path
# test_real_dataset_2d
# test_correct_experiment_routing
# test_runs_from_different_experiments_raises
# test_extracting_dataless_run
# test_result_table_naming_and_run_id
# test_load_by_X_functions
# test_combine_runs
# test_copy_datasets_and_add_new
# test_old_versions_not_touched
# test_experiments_with_NULL_sample_name
# test_integration_station_and_measurement
# test_atomicity
# test_column_mismatch
# callback
# reset_callback_globals
# test_default_callback
# test_numpy_types
# test_saving_numeric_values_as_text
# test_duplicated_parameter_raises
# make_shadow_dataset
# test_has_attributes_after_init
# test_dataset_length
# test_dataset_location
# test_dataset_states
# test_mark_completed_twice
# test_timestamps_are_none
# test_integer_timestamps_in_database_are_supported
# test_dataset_read_only_properties
# test_create_dataset_from_non_existing_run_id
# test_create_dataset_pass_both_connection_and_path_to_db
# test_load_by_id
# test_load_by_id_for_nonexisting_run_id
# test_load_by_id_for_none
# test_add_experiments
# test_dependent_parameters
# test_set_interdependencies
# test_add_data_1d
# test_add_data_array
# test_adding_too_many_results
# test_load_by_counter
# test_load_by_counter_for_nonexisting_counter
# test_load_by_counter_for_nonexisting_experiment
# test_dataset_with_no_experiment_raises
# test_guid
# test_numpy_ints
# test_numpy_floats
# test_numpy_complex
# test_numpy_nan
# test_numpy_inf
# test_backward_compat__adapt_array_v0_33
# test_missing_keys
# test_get_description
# test_metadata
# test_the_same_dataset_as
# test_parent_dataset_links_invalid_input
# test_parent_dataset_links
# TestGetData
# ds_with_vals
# test_get_data_with_start_and_end_args
# test_get_parameter_data
# test_get_scalar_parameter_data_no_nulls
# test_get_array_parameter_data_no_nulls
# test_get_array_parameter_data
# test_get_multi_parameter_data
# test_get_array_in_scalar_param_data
# test_get_varlen_array_in_scalar_param_data
# test_get_array_in_scalar_param_unrolled
# test_get_array_in_str_param_data
# test_get_parameter_data_independent_parameters
# parameter_test_helper
# limit_data_to_start_end
# test_empty_ds_parameters
# _make_mock_empty_dataset
# _make_mock_dataset
# _make_mock_dataset_nonunique_index
# _make_mock_dataset_label_unit
# _make_mock_dataset_complex
# _make_mock_dataset_inverted_coords
# test_write_data_to_text_file_save
# test_write_data_to_text_file_save_multi_keys
# test_write_data_to_text_file_save_single_file
# test_write_data_to_text_file_length_exception
# test_write_data_to_text_file_name_exception
# test_export_csv
# test_export_netcdf
# test_export_netcdf_default_dir
# test_export_netcdf_csv
# test_export_netcdf_complex_data
# test_export_no_or_nonexistent_type_specified
# test_export_from_config
# test_export_from_config_set_name_elements
# test_same_setpoint_warning_for_df_and_xarray
# test_export_to_xarray_dataset_empty_ds
# test_export_to_xarray_dataarray_empty_ds
# test_export_to_xarray
# test_export_to_xarray_non_unique_dependent_parameter
# test_export_to_xarray_extra_metadata
# test_export_to_xarray_ds_dict_extra_metadata
# test_export_to_xarray_extra_metadata_can_be_stored
# test_to_xarray_ds_paramspec_metadata_is_preserved
# test_to_xarray_da_dict_paramspec_metadata_is_preserved
# test_inverted_coords_perserved_on_netcdf_roundtrip
# _get_expected_param_spec_attrs
# _assert_xarray_metadata_is_as_expected
# test_dataset_in_memory_reload_from_db
# test_dataset_in_memory_reload_from_db_2d
# test_dataset_in_memory_reload_from_db_3d
# test_dataset_in_memory_without_cache_raises
# test_dataset_in_memory_reload_from_db_complex
# test_dataset_in_memory_reload_from_netcdf_complex
# test_dataset_in_memory_no_export_warns
# test_dataset_in_memory_missing_file_warns
# test_dataset_in_reload_from_netcdf
# test_dataset_load_from_netcdf_and_db
# test_dataset_in_memory_does_not_create_runs_table
# test_load_from_netcdf_and_write_metadata_to_db
# test_load_from_netcdf_no_db_file
# test_load_from_db
# test_load_from_netcdf_legacy_version
# compare_datasets
# test_load_from_db_dataset_moved
# test_create_dataset_in_memory_explicit_db
# test_empty_ds_parameters
# test_write_metadata_to_explicit_db
# test_no_interdeps_raises_in_prepare
# test_prepare_twice_raises
# test_timestamps
# test_mark_pristine_completed_raises
# test_load_from_non_existing_guid
# test_load_by_id
# test_get_guids_from_run_spec_warns
# test_load_by_counter
# test_get_run_attributes
# test_experiment_info_in_dataset
# test_run_timestamp
# test_run_timestamp_with_default_format
# test_completed_timestamp
# test_completed_timestamp_for_not_completed_dataset
# test_completed_timestamp_with_default_format
# test_load_by_guid
# test_load_by_run_spec
# test_callback
# test_cache_standalone
# test_cache_1d
# test_cache_1d_every_other_point
# test_cache_2d
# test_cache_2d_num_with_multiple_storage_types
# test_cache_1d_array_in_1d
# test_cache_multiparam_in_1d
# test_cache_complex_array_param_in_1d
# test_cache_1d_shape
# test_cache_2d_shape
# _assert_completed_cache_is_as_expected
# _assert_partial_cache_is_as_expected
# _assert_parameter_data_is_identical
# _array_param_used_in_tree
# _prepare_setpoints_1d
# test_wrong_input_raises
# test_init
# test_init_validation_raises
# test_to_dict
# test_old_to_new_and_back
# test_old_to_new
# test_new_to_old
# test_extend_with_paramspec
# test_validate_subset
# test_extend
# test_remove
# test_equality_old
# test_non_dependents
# test_wrong_input_type_raises
# test_equality
# test_keys_of_result_of_to_dict
# test_to_and_from_dict_roundtrip
# test_yaml_creation_and_loading
# test_jsonization_as_v0_for_storage
# test_default_jsonization_for_storage
# test_dictization_as_v0_for_storage
# test_default_dictization_for_storage
# test_dictization_of_current_version
# test_get_shape_for_parameter_from_len
# test_get_shape_for_parameter_from_sequence
# test_get_shape_for_array_parameter_from_len
# test_get_shape_for_array_parameter_from_shape
# test_get_shape_for_multiparam_from_len
# test_get_shape_for_multiparam_from_shape
# test_get_shape_for_pws_from_len
# test_get_shape_for_pws_from_shape
# test_get_shape_for_param_with_array_validator_from_shape
# test_get_shape_for_multiple_parameters
# assert_experiments_equal
# test_run_loaded_experiment
# test_last_data_set_from_experiment
# test_last_data_set_from_experiment_with_no_datasets
# test_load_or_create_experiment_loading
# test_load_or_create_experiment_different_sample_name
# test_load_or_create_experiment_creating
# test_load_or_create_experiment_creating_not_empty
# test_has_attributes_after_init
# test_experiment_read_only_properties
# test_create_experiment_from_non_existing_id
# test_load_experiment_from_non_existing_id
# test_load_experiment_from_bad_id
# test_format_string
# test_load_experiment_by_name_defaults
# test_load_experiment_by_name
# test_load_experiment_by_name_bad_name
# test_load_experiment_by_name_bad_sample_name
# test_load_experiment_by_name_duplicate_name
# test_load_experiment_by_name_duplicate_sample_name
# test_load_experiment_by_name_duplicate_name_and_sample_name
# test_new_experiment_duplicate_name_and_sample_name
# test_load_last_experiment
# test_active_experiment
# _make_basic_export_info
# test_export_info_basic
# test_invalid_key_raises
# test_export_info_json_roundtrip
# test_init_from_empty_str
# test_version_4a_bugfix
# test_version_4a_bugfix_raises
# test_fix_wrong_run_descriptions
# test_fix_wrong_run_descriptions_raises
# _make_seed_random
# test_generate_guid
# test_set_guid_location_code
# test_set_guid_workstation_code
# test_filter_guid
# test_validation
# test_random_sample_guid
# test_random_sample_and_sample_int_in_guid_raises
# test_sample_int_in_guid_warns
# test_guids_from_dir
# test_guids_from_list_str
# test_many_guids_from_list_str
# test_get_guids_from_multiple_run_ids
# generate_some_links
# test_link_construction_passes
# test_link_construction_raises
# test_link_to_str
# test_str_to_link
# test_link_to_string_and_back
# test_links_to_str_and_back
# test_get_metadata_from_dataset
# test_get_nonexisting_metadata
# test_get_metadata_lower_upper_case
# test_nested_measurement_basic
# test_nested_measurement
# test_nested_measurement_array
# basic_subscriber
# test_subscription_on_dual_datasets
# valid_identifier
# version_0_dicts
# version_0_objects
# test_creation
# test_repr
# test_depends_on
# test_inferred_from
# test_copy
# test_convert_to_dict
# test_from_dict
# test_hash
# test_hash_with_deferred_and_inferred_as_paramspecs
# test_base_version
# test_not_eq_for_list_attr
# test_not_eq_for_str_attr
# test_not_eq_non_paramspec
# TerminateLoopException
# test_rescaled_ticks_and_units
# test_plot_by_id_line_and_heatmap
# test_plot_dataset_2d_shaped
# test_appropriate_kwargs
# test__complex_to_real_preparser_complex_toplevel_param
# test__complex_to_real_preparser_complex_setpoint
# dac
# dmm
# test_station_snapshot_during_measurement
# test_snapshot_creation_for_types_not_supported_by_builtin_json
# test_settings_exist
# shadow_conn
# _make_simple_run_describer
# test_path_to_dbfile
# test_one_raises_on_no_results
# test_one_raises_on_more_than_one_result
# test_one_raises_on_wrong_column_name
# test_one_raises_on_wrong_column_index
# test_one_works_if_given_column_index
# test_one_works_if_given_column_name
# test_atomic_transaction_raises
# test_atomic_raises
# test_insert_many_values_raises
# test_get_non_existing_metadata_returns_none
# test__validate_table_raises
# test_get_dependents_simple
# test_get_dependents
# test_column_in_table
# test_run_exist
# test_get_last_run
# test_get_last_run_no_runs
# test_get_last_experiment
# test_get_last_experiment_no_experiments
# test_update_runs_description
# test_runs_table_columns
# test_get_data_no_columns
# test_get_parameter_data
# test_get_parameter_data_independent_parameters
# test_is_run_id_in_db
# test_atomic_creation
# test_set_run_timestamp
# test_set_run_timestamp_explicit
# test_mark_run_complete
# test_mark_run_complete_twice
# test_mark_run_complete_explicit_time
# sqlite_conn_in_transaction
# conn_plus_in_transaction
# sqlite_conn_is_idle
# conn_plus_is_idle
# test_connection_plus
# test_make_connection_plus_from_sqlite3_connection
# test_make_connection_plus_from_connecton_plus
# test_atomic
# test_atomic_with_exception
# test_atomic_on_outmost_connection_that_is_in_transaction
# test_atomic_on_connection_plus_that_is_in_progress
# test_two_nested_atomics
# test_that_use_of_atomic_commits_only_at_outermost_context
# test_atomic_transaction
# test_atomic_transaction_on_sqlite3_connection_raises
# test_connect
# test_string_via_dataset
# test_string_via_datasaver
# test_string
# test_string_with_wrong_paramtype
# test_string_with_wrong_paramtype_via_datasaver
# test_string_saved_and_loaded_as_numeric_via_dataset
# test_list_of_strings
# test_string_and_date_data_in_array
# MockSubscriber
# __init__
# __call__
# config_subscriber_factory
# basic_subscriber
# _make_working_subscriber_config
# _make_broken_subscriber_config
# test_basic_subscription
# test_subscription_from_config
# test_subscription_from_config_wrong_name
# test_get_data_by_id_order
# test_datasaver_multidimarrayparameter_as_array
# test_datasaver_multidimarrayparameter_as_numeric
# test_datasaver_array_parameters_channel
# test_datasaver_array_parameters_array
# test_datasaver_multidim_array
# test_datasaver_multidim_numeric
# set_tmp_output_dir
# plot_close
# _param
# _param_2
# _param_complex
# _param_complex_2
# _param_set
# _param_set_2
# _param_func
# _param_callable
# test_param_callable
# _string_callable
# test_do0d_with_real_parameter
# test_do0d_with_complex_parameter
# test_do0d_with_a_callable
# test_do0d_with_2_parameters
# test_do0d_with_parameter_and_a_callable
# test_do0d_output_type_real_parameter
# test_do0d_output_type_complex_parameter
# test_do0d_output_type_callable
# test_do0d_output_data
# test_do0d_verify_shape
# test_do0d_parameter_with_array_vals
# test_do0d_explicit_experiment
# test_do0d_explicit_name
# test_do0d_parameter_with_setpoints_2d
# test_dond_0d_output_type
# test_do1d_with_real_parameter
# test_do1d_plot
# test_do1d_with_complex_parameter
# test_do1d_with_2_parameter
# test_do1d_output_type_real_parameter
# test_do1d_output_data
# test_do1d_verify_shape
# test_do1d_parameter_with_array_vals
# test_do1d_explicit_experiment
# test_do1d_explicit_name
# test_do1d_additional_setpoints
# test_do1d_additional_setpoints_shape
# test_do1d_break_condition
# test_do2d
# test_do2d_plot
# test_do2d_output_type
# test_do2d_output_data
# test_do2d_verify_shape
# test_do2d_additional_setpoints
# test_do2d_additional_setpoints_shape
# test_do2d_explicit_experiment
# test_do2d_explicit_name
# TrackingParameter
# __init__
# set_raw
# get_raw
# reset_count
# GetReturnsCountParameter
# __init__
# set_raw
# get_raw
# reset_count
# test_linear_sweep_get_setpoints
# test_linear_sweep_properties
# test_linear_sweep_parameter_class
# test_log_sweep_get_setpoints
# test_log_sweep_properties
# test_log_sweep_parameter_class
# test_array_sweep_get_setpoints
# test_array_sweep_properties
# test_array_sweep_parameter_class
# test_dond_explicit_exp_meas_sample
# test_dond_multi_datasets_explicit_exp_meas_sample
# test_dond_multi_datasets_explicit_meas_names
# test_dond_multi_datasets_meas_names_len_mismatch
# test_dond_0d_verify_shape
# test_dond_0d_output_data
# test_dond_0d_parameter_with_array_vals
# test_dond_0d_with_real_parameter
# test_dond_0d_parameter_with_setpoints_2d
# test_dond_1d_parameter_with_array_vals
# test_dond_1d_verify_shape
# test_dond_1d_additional_setpoints
# test_dond_1d_additional_setpoints_shape
# test_dond_1d_plot
# test_dond_1d_output_data
# test_dond_1d_output_type
# test_dond_2d_verify_shape
# test_dond_2d_additional_setpoints
# test_dond_2d_additional_setpoints_shape
# test_dond_2d_plot
# test_dond_2d_output_type
# test_dond_2d_output_data
# test_dond_2d_multi_datasets_output_type
# test_dond_2d_multi_datasets_multi_exp
# test_dond_2d_multi_datasets_multi_exp_inconsistent_raises
# test_dond_2d_multiple_datasets_plot
# test_dond_2d_multi_datasets_with_callable_output_data
# test_dond_together_sweep
# test_dond_together_sweep_sweeper
# test_dond_together_sweep_sweeper_combined
# test_dond_together_sweep_sweeper_combined_2_in_1
# test_dond_together_sweep_sweeper_mixed_splitting
# test_dond_together_sweep_sweeper_combined_explict_names
# test_dond_together_sweep_sweeper_combined_explict_names_inconsistent
# test_dond_together_sweep_sweeper_combined_explict_names_and_single_name
# test_dond_together_sweep_sweeper_combined_lists
# test_together_sweep_validation
# test_empty_together_sweep_raises
# test_dond_together_sweep_more_parameters
# test_dond_together_sweep_sweeper_combined_missing_in_dataset_dependencies
# test_dond_together_sweep_sweeper_wrong_sp_in_dataset_dependencies
# test_dond_together_sweep_sweeper_wrong_mp_in_dataset_dependencies
# test_dond_together_sweep_parameter_with_setpoints
# test_dond_together_sweep_parameter_with_setpoints_explicit_mapping
# test_dond_together_sweep_parameter_with_setpoints_explicit_mapping_and_callable
# test_dond_sweeper_combinations
# test_sweep_int_vs_float
# test_error_no_measured_parameters
# test_error_measured_grouped_and_not_grouped
# test_post_action
# test_extra_log_info
# test_default_log_info
# test_dond_get_after_set
# test_dond_no_get_after_set
# test_dond_get_after_set_stores_get_value
# test_load_legacy_files_2d
# test_load_legacy_files_1d
# test_load_legacy_files_1d_pathlib_path
# test_log_messages
# test_log_includes_extra_info
# test_register_parameter_numbers
# test_register_custom_parameter
# test_unregister_parameter
# test_mixing_array_and_numeric
# test_measurement_name_default
# test_measurement_name_changed_via_attribute
# test_measurement_name_set_as_argument
# test_setting_write_period
# test_setting_write_period_from_config
# test_setting_write_in_background_from_config
# test_method_chaining
# test_enter_and_exit_actions
# test_subscriptions
# test_subscribers_called_at_exiting_context_if_queue_is_not_empty
# test_subscribers_called_for_all_data_points
# test_datasaver_scalars
# test_datasaver_inst_metadata
# test_exception_happened_during_measurement_is_stored_in_dataset_metadata
# test_datasaver_arrays_lists_tuples
# test_datasaver_numeric_and_array_paramtype
# test_datasaver_numeric_after_array_paramtype
# test_datasaver_foul_input
# test_datasaver_unsized_arrays
# test_datasaver_arrayparams
# test_datasaver_array_parameters_channel
# test_datasaver_parameter_with_setpoints
# test_datasaver_parameter_with_setpoints_explicitly_expanded
# test_datasaver_parameter_with_setpoints_partially_expanded_raises
# test_datasaver_parameter_with_setpoints_complex
# test_datasaver_parameter_with_setpoints_complex_explicitly_expanded
# test_datasaver_parameter_with_setpoints_missing_reg_raises
# test_datasaver_parameter_with_setpoints_reg_but_missing_validator
# test_datasaver_parameter_with_setpoints_reg_but_missing
# test_datasaver_array_parameters_array
# test_datasaver_complex_array_parameters_array
# test_datasaver_multidim_array
# test_datasaver_export
# test_datasaver_multidim_numeric
# test_datasaver_multidimarrayparameter_as_array
# test_datasaver_multidimarrayparameter_as_numeric
# test_datasaver_multi_parameters_scalar
# test_datasaver_multi_parameters_array
# test_datasaver_2d_multi_parameters_array
# test_datasaver_arrays_of_different_length
# test_save_complex_num
# test_save_and_reload_complex_standalone
# test_save_complex_num_setpoints
# test_save_complex_num_setpoints_array
# test_save_complex_as_num_raises
# test_save_numeric_as_complex_raises
# test_parameter_inference
# test_adding_parents
# test_datasaver_1d
# test_datasaver_2d
# dac
# field_x
# lockin
# station
# chip_config
# chip
# chip_config_typo
# test_mock_dac
# test_mock_field_delegate
# test_delegate_channel_instrument
# test_device
# test_device_meas
# test_device_with_channels
# test_device_with_custom_channels
# test_chip_definition
# TestAgilentE8257D
# setUpClass
# test_firmware_version
# test_on_off
# test_frequency
# test_power
# test_phase
# _make_driver
# test_idn
# magnet_axes_instances
# _make_current_driver
# _make_ami430
# test_instantiation_from_names
# test_instantiation_from_name_of_nonexistent_ami_instrument
# test_instantiation_from_name_of_existing_non_ami_instrument
# test_instantiation_from_badly_typed_argument
# test_cartesian_sanity
# test_spherical_sanity
# test_cylindrical_sanity
# test_cartesian_setpoints
# test_spherical_setpoints
# test_cylindrical_setpoints
# test_measured
# get_ramp_down_order
# test_ramp_down_first
# test_field_limit_exception
# test_cylindrical_poles
# test_spherical_poles
# test_ramp_rate_exception
# test_simultaneous_ramp_mode_does_not_reset_individual_axis_ramp_rates_if_nonblocking_ramp
# test_simultaneous_ramp_mode_resets_individual_axis_ramp_rates_if_blocking_ramp
# test_reducing_field_ramp_limit_reduces_a_higher_ramp_rate
# test_reducing_current_ramp_limit_reduces_a_higher_ramp_rate
# test_reducing_field_ramp_limit_keeps_a_lower_ramp_rate_as_is
# test_reducing_current_ramp_limit_keeps_a_lower_ramp_rate_as_is
# test_blocking_ramp_parameter
# test_current_and_field_params_interlink_at_init
# test_current_and_field_params_interlink__change_current_ramp_limit
# test_current_and_field_params_interlink__change_field_ramp_limit
# test_current_and_field_params_interlink__change_coil_constant
# test_current_and_field_params_interlink__permutations_of_tests
# _parametrization_kwargs
# test_numeric_field_limit
# test_ramp_rate_units_and_field_units_at_init
# test_change_ramp_rate_units_parameter
# test_change_field_units_parameter
# test_switch_heater_enabled
# magnet_axes_instances
# _make_current_driver
# _make_ami430
# test_instantiation_from_names
# test_instantiation_compat_classes
# test_instantiation_from_name_of_nonexistent_ami_instrument
# test_instantiation_from_name_of_existing_non_ami_instrument
# test_instantiation_from_badly_typed_argument
# test_cartesian_sanity
# test_spherical_sanity
# test_cylindrical_sanity
# test_cartesian_setpoints
# test_spherical_setpoints
# test_cylindrical_setpoints
# test_measured
# get_ramp_down_order
# test_ramp_down_first
# test_field_limit_exception
# test_cylindrical_poles
# test_spherical_poles
# test_ramp_rate_exception
# test_simultaneous_ramp_mode_does_not_reset_individual_axis_ramp_rates_if_nonblocking_ramp
# test_simultaneous_ramp_mode_resets_individual_axis_ramp_rates_if_blocking_ramp
# test_reducing_field_ramp_limit_reduces_a_higher_ramp_rate
# test_reducing_current_ramp_limit_reduces_a_higher_ramp_rate
# test_reducing_field_ramp_limit_keeps_a_lower_ramp_rate_as_is
# test_reducing_current_ramp_limit_keeps_a_lower_ramp_rate_as_is
# test_blocking_ramp_parameter
# test_current_and_field_params_interlink_at_init
# test_current_and_field_params_interlink__change_current_ramp_limit
# test_current_and_field_params_interlink__change_field_ramp_limit
# test_current_and_field_params_interlink__change_coil_constant
# test_current_and_field_params_interlink__permutations_of_tests
# _parametrization_kwargs
# test_numeric_field_limit
# test_ramp_rate_units_and_field_units_at_init
# test_change_ramp_rate_units_parameter
# test_change_field_units_parameter
# test_switch_heater_enabled
# k2450
# test_wrong_mode
# test_change_source_function
# test_source_change_error
# test_sense_current_mode
# test_setpoint_always_follows_source_function
# test_reset_sweep_on_source_change
# test_sweep
# _make_driver
# _make_smus
# test_idn
# test_smu_channels_and_their_parameters
# test_setting_source_voltage_range_disables_autorange
# test_setting_measure_voltage_range_disables_autorange
# test_setting_source_current_range_disables_autorange
# test_setting_measure_current_range_disables_autorange
# _make_driver
# channels_in_slot_one
# channels_in_slot_two
# channels_in_slot_three
# matrix_channels
# test_idn
# test_switch_card_idn
# test_installed_card_id
# test_slot_names
# test_get_interlock_state
# test_get_number_of_rows
# test_get_number_of_columns
# test_get_rows
# test_get_columns
# test_number_of_channels_by_slot
# test_total_number_of_channels
# test_channels_in_slot_one
# test_channels_in_slot_two
# test_channels_in_slot_three
# test_matrix_channels
# test_analog_backplane_specifiers
# test_validator_truth
# test_validator_falsehood
# dmm_7510_driver
# test_get_idn
# test_change_sense_function
# test_set_range_and_nplc
# test_aliases_dict
# s46_six
# s46_four
# test_runtime_error_on_bad_init
# test_query_close_once_at_init
# test_init_six
# test_init_four
# test_channel_number_invariance
# test_locking_mechanism
# test_is_closed
# driver
# test_init
# test_sync
# test_channel
# test_burst
# driver
# driver_with_read_and_fetch_mocked
# test_init
# test_has_dig_option
# test_model_flag
# test_reset
# test_NPLC
# test_get_voltage
# test_get_voltage_plus_inf
# test_get_voltage_minus_inf
# test_get_timetrace
# test_set_get_autorange
# test_increase_decrease_range
# test_display_text
# switch_driver
# test_protection_mode
# test_connection
# test_4x32
# test_4x64
# test_4x128
# test_8x32
# test_8x64
# test_16x32
# numbering_function_4x32
# numbering_function_4x64
# numbering_function_4x128
# numbering_function_8x32
# numbering_function_8x64
# numbering_function_16x32
# switch_driver
# test_safety_interlock_during_init
# test_get_idn
# test_scan_slots
# test_safety_interlock
# uut
# test_idn_command
# test_connect
# test_connect_throws_at_invalid_channel_number
# test_connect_emits_warning_on_statusbyte_not_null
# test_disconnect_throws_at_invalid_channel_number
# test_connections
# test_to_channel_list
# test_connect_paths
# test_disconnect_paths
# test_disconnect_all
# test_disconnect
# test_connection_rule
# test_connection_rule_emits_warning_when_going_from_free_to_single
# test_connection_sequence
# test_bias_disable_all_outputs
# test_bias_disable_ouput
# test_bias_enable_all_outputs
# test_bias_enable_output
# test_bias_input_port
# test_bias_mode
# test_gnd_disable_all_outputs
# test_gnd_disable_output
# test_gnd_enable_all_outputs
# test_gnd_enable_output
# test_gnd_input_port
# test_gnd_mode
# test_unused_inputs
# test_couple_mode
# test_couple_ports
# test_couple_port_autodetect
# test_get_error
# TestParseChannelList
# test_parse_channel_list
# test_all_combinations_zero_padded
# test_all_combinations_unpadded
# _make_driver
# test_idn
# test_raise_error_for_volt_level_query_when_signal_set_as_current
# test_voltage_level_set_method
# test_signal_mode_parameter
# test_raise_error_for_curr_level_query_when_signal_set_as_voltage
# test_current_level_set_method
# _make_driver
# test_idn
# test_channels
# _make_driver
# _activate_swept_sa_measurement
# _activate_log_plot_measurement
# test_idn
# test_swept_sa_setup
# test_log_plot_setup
# MockVisaInstrument
# __init__
# write_raw
# ask_raw
# query
# command
# split_args
# DictClass
# __init__
# __getattr__
# __setattr__
# Model_372_Mock
# __init__
# start_heating
# get_t_when_heating
# pidq
# pid
# outmodeq
# outputmode
# insetq
# inset
# intypeq
# intype
# rangeq
# range_cmd
# setpointq
# setpoint
# tlimitq
# tlimitcmd
# temperature
# instrument_fixture
# lakeshore_372
# test_pid_set
# test_output_mode
# test_range
# test_tlimit
# test_setpoint
# test_select_range_limits
# test_set_and_wait_unit_setpoint_reached
# test_blocking_t
# test_get_term_sum
# test_get_term_sum_with_some_powers_of_2_omitted
# test_get_term_sum_returns_empty_list
# test_get_term_sum_when_zero_is_not_in_available_terms
# test_decode_sensor_status
# test_decode_sensor_status_0
# test_decode_sensor_status
# test_decode_sensor_status_0
# LakeshoreModel336Mock
# __init__
# start_heating
# get_t_when_heating
# pidq
# pid
# outmodeq
# outputmode
# intypeq
# intype
# rangeq
# range_cmd
# setpointq
# setpoint
# tlimitq
# tlimitcmd
# temperature
# _make_lakeshore_336
# test_pid_set
# test_output_mode
# test_range
# test_tlimit
# test_setpoint
# test_select_range_limits
# test_set_and_wait_unit_setpoint_reached
# test_blocking_t
# Model_336_Mock
# __init__
# start_heating
# get_t_when_heating
# pidq
# pid
# outmodeq
# outputmode
# intypeq
# intype
# rangeq
# range_cmd
# setpointq
# setpoint
# tlimitq
# tlimitcmd
# temperature
# lakeshore_336
# test_pid_set
# test_output_mode
# test_range
# test_tlimit
# test_setpoint
# test_select_range_limits
# test_set_and_wait_unit_setpoint_reached
# test_blocking_t
# curve_file
# test_file_parser
# test_sanitise_data
# driver
# driver_spher_lim
# driver_cyl_lim
# test_idn
# test_simple_setting
# test_vector_setting
# test_vector_ramp_rate
# test_wrong_field_limit_raises
# test_field_limits
# get_ramp_order
# test_ramp_safely
# driver
# test_initialize
# test_gets_correct_waveform_xorigin
# test_gets_correct_waveform_xincrem
# test_sets_correct_waveform_npoints
# test_gets_correct_waveform_yorigin
# test_gets_correct_waveform_yincrem
# test_gets_correct_waveform_yref
# test_sets_correct_trigger_mode
# test_get_data_source
# driver
# test_init
# test_trigger_source_level
# stahl_instrument
# test_parse_idn_string
# test_get_idn
# test_get_set_voltage
# test_get_set_voltage_assert_warning
# test_get_current
# test_get_temperature
# awg
# test_init_awg
# test_pack_waveform
# test_make_awg_file
# awg
# test_init_awg
# test_channel_resolution_docstring
# strip_outer_tags
# awg2
# random_wfm_m1_m2_package
# _make_forged_sequence
# test_init_awg2
# test_SML_successful_generation_vary_length
# test_WFMXHeader_succesful
# test_WFMXHeader_failing
# test_seqxfilefromfs_failing
# test_seqxfilefromfs_warns
# test_seqxfile_from_fs
# test_makeSEQXFile
# tektronix_dpo
# test_adjust_timer
# test_measurements_return_float
# test_measurement_sets_state
# TestWeinschel8320
# test_firmware_version
# test_attenuation
# _make_gs200
# test_basic_init
# test_current_raises_in_voltage_mode
# test_voltage_raises_in_current_mode
# _skip_if_alazar_dll_and_boards_not_installed
# alazar
# alazar_api
# test_alazar_api_singleton_behavior
# test_find_boards
# test_get_board_info
# test_idn
# test_return_codes_are_correct
# test_get_channel_info_convenient
# test_get_cpld_version_convenient
# test_get_driver_version_convenient
# test_get_sdk_version_convenient
# test_query_capability_convenient
# test_writing_and_reading_registers
# test_get_num_channels
# test_buffer_is_allocated_when_initiated
# test_supported_ctypes_for_sample
# test_wrapped_dll_singleton_behavior
# uut
# test_append
# test_set_final
# test_clear
# test_string_representation
# mb
# test_as_csv
# _skip
# test_cmd
# test_raise_error_on_appending_command_after_final_command
# test_exception_on_too_long_message
# test_clear_message_queue
# test_aad
# test_ab
# test_ach
# test_act
# test_acv
# test_adj
# test_adj_query
# test_ait
# test_aitm
# test_aitm_query
# test_als
# test_als_query
# test_alw
# test_alw_query
# test_av
# test_az
# test_bc
# test_bdm
# test_bdt
# test_bdv
# test_bgi
# test_bgv
# test_bsi
# test_bsm
# test_bssi
# test_bssv
# test_bst
# test_bsv
# test_bsvm
# test_ca
# test_cal_query
# test_cl
# test_clcorr
# test_cm
# test_cmm
# test_cn
# test_cnx
# test_corr_query
# test_corrdt
# test_corrdt_query
# test_corrl
# test_corrl_query
# test_corrser_query
# test_corrst
# test_corrst_query
# test_dcorr
# test_dcorr_query
# test_dcv
# test_di
# test_diag_query
# test_do
# test_dsmplarm
# test_dsmplflush
# test_dsmplsetup
# test_dv
# test_dz
# test_emg_query
# test_end
# test_erc
# test_ercmaa
# test_ercmaa_query
# test_ercmagrd
# test_ercmagrd_query
# test_ercmaio
# test_ercmaio_query
# test_ercmapfgd
# test_erhpa
# test_erhpa_query
# test_erhpe
# test_erhpe_query
# test_erhpl
# test_erhpl_query
# test_erhpp
# test_erhpp_query
# test_erhpqg
# test_erhpqg_query
# test_erhpr
# test_erhpr_query
# test_erhps
# test_erhps_query
# test_erhvca
# test_erhvca_query
# test_erhvctst_query
# test_erhvp
# test_erhvp_query
# test_erhvpv
# test_erhvs
# test_erhvs_query
# test_erm
# test_ermod
# test_ermod_query
# test_erpfda
# test_erpfda_query
# test_erpfdp
# test_erpfdp_query
# test_erpfds
# test_erpfds_query
# test_erpfga
# test_erpfga_query
# test_erpfgp
# test_erpfgp_query
# test_erpfgr
# test_erpfgr_query
# test_erpfqg
# test_erpfqg_query
# test_erpftemp_query
# test_erpfuhca
# test_erpfuhca_query
# test_erpfuhccal_query
# test_erpfuhcmax_query
# test_erpfuhctst
# test_err_query
# test_errx_query
# test_ers_query
# test_erssp
# test_erssp_query
# test_eruhva
# test_eruhva_query
# test_fc
# test_fl
# test_fmt
# test_hvsmuop
# test_hvsmuop_query
# test_idn_query
# test_imp
# test_in_
# test_intlkvth
# test_intlkvth_query
# test_lgi
# test_lgv
# test_lim
# test_lim_query
# test_lmn
# test_lop_query
# test_lrn_query
# test_lsi
# test_lsm
# test_lssi
# test_lssv
# test_lst_query
# test_lstm
# test_lsv
# test_lsvm
# test_mcc
# test_mcpnt
# test_mcpnx
# test_mcpt
# test_mcpws
# test_mcpwnx
# test_mdcv
# test_mi
# test_ml
# test_mm
# test_msc
# test_msp
# test_mt
# test_mtdcv
# test_mv
# test_nub_query
# test_odsw
# test_odsw_query
# test_opc_query
# test_os
# test_osx
# test_pa
# test_pad
# test_pax
# test_pch
# test_pch_query
# test_pdcv
# test_pi
# test_pt
# test_ptdcv
# test_pv
# test_pwdcv
# test_pwi
# test_pwv
# test_qsc
# test_qsl
# test_qsm
# test_qso
# test_qsr
# test_qst
# test_qsv
# test_qsz
# test_rc
# test_rcv
# test_ri
# test_rm
# test_rst
# test_ru
# test_rv
# test_rz
# test_sal
# test_sap
# test_sar
# test_scr
# test_ser
# test_ser_query
# test_sim
# test_sim_query
# test_sopc
# test_sopc_query
# test_sovc
# test_sovc_query
# test_spm
# test_spm_query
# test_spp
# test_spper
# test_spper_query
# test_sprm
# test_sprm_query
# test_spst_query
# test_spt
# test_spt_query
# test_spupd
# test_spv
# test_spv_query
# test_sre
# test_sre_query
# test_srp
# test_ssl
# test_ssp
# test_ssr
# test_st
# test_stb_query
# test_stgp
# test_stgp_query
# test_tacv
# test_tc
# test_tdcv
# test_tdi
# test_tdv
# test_tgmo
# test_tgp
# test_tgpc
# test_tgsi
# test_tgso
# test_tgxo
# test_ti
# test_tiv
# test_tm
# test_tmacv
# test_tmdcv
# test_tsc
# test_tsq
# test_tsr
# test_tst
# test_ttc
# test_tti
# test_ttiv
# test_ttv
# test_tv
# test_unt_query
# test_var
# test_var_query
# test_wacv
# test_wat
# test_wdcv
# test_wfc
# test_wi
# test_wm
# test_wmacv
# test_wmdcv
# test_wmfc
# test_wncc
# test_wnu_query
# test_wnx
# test_ws
# test_wsi
# test_wsv
# test_wt
# test_wtacv
# test_wtdcv
# test_wtfc
# test_wv
# test_wz_query
# test_xe
# test_nplc_setting_for_high_speed_vs_high_resolution_mode
# test_set_resolution_mode_for_each_smu
# _make_b1500
# _make_mainframe
# test_make_module_from_model_name
# test_init
# test_snapshot_does_not_raise_warnings
# test_submodule_access_by_class
# test_submodule_access_by_slot
# test_submodule_access_by_channel
# test_enable_multiple_channels
# test_disable_multiple_channels
# test_use_nplc_for_high_speed_adc
# test_use_nplc_for_high_resolution_adc
# test_autozero_enabled
# test_use_manual_mode_for_high_speed_adc
# test_self_calibration_successful
# test_self_calibration_failed
# test_error_message
# test_clear_timer_count
# test_set_measuremet_mode
# test_get_measurement_mode
# test_get_response_format_and_mode
# test_enable_smu_filters
# test_error_message_is_called_after_setting_a_parameter
# test_is_enabled
# test_enable_outputs
# test_disable_outputs
# test_parse_module_query_response
# test_format_dcorr_response
# test_fixed_negative_float
# test_get_name_label_unit_of_impedance_model
# test_convert_dummy_val_to_nan
# _make_smu
# test_force_invalid_current_output_range_when_asu_not_present
# test_i_measure_range_config_raises_invalid_range_error_when_asu_not_present
# _make_smu
# test_snapshot
# test_measure_config
# test_v_measure_range_config_raises_type_error
# test_v_measure_range_config_raises_invalid_range_error
# test_v_measure_range_config_sets_range_correctly
# test_getting_voltage_after_calling_v_measure_range_config
# test_i_measure_range_config_raises_type_error
# test_i_measure_range_config_raises_invalid_range_error
# test_i_measure_range_config_sets_range_correctly
# test_getting_current_after_calling_i_measure_range_config
# test_force_invalid_voltage_output_range
# test_force_invalid_current_output_range
# test_force_voltage_with_autorange
# test_force_voltage_autorange_and_compliance
# test_new_source_config_should_invalidate_old_source_config
# test_unconfigured_source_defaults_to_autorange_v
# test_unconfigured_source_defaults_to_autorange_i
# test_force_current_with_autorange
# test_raise_warning_output_range_mismatches_output_command
# test_measure_current
# test_measure_voltage
# test_measure_current_shows_compliance_hit
# test_measured_voltage_with_V_status_returns_nan
# test_some_voltage_sourcing_and_current_measurement
# test_use_high_resolution_adc
# test_use_high_speed_adc
# test_measurement_mode_at_init
# test_measurement_mode_to_enum_value
# test_measurement_mode_to_int_value
# test_setting_timing_parameters
# test_set_average_samples_for_high_speed_adc
# test_measurement_operation_mode
# test_current_measurement_range
# test_get_sweep_mode_range_start_end_steps
# test_iv_sweep_delay
# test_iv_sweep_mode_start_end_steps_compliance
# test_set_sweep_auto_abort
# test_get_sweep_auto_abort
# test_set_post_sweep_voltage_cond
# test_get_post_sweep_voltage_cond
# _make_cmu
# test_force_dc_voltage
# test_force_ac_voltage
# test_set_ac_frequency
# test_get_dc_voltage
# test_get_ac_voltage
# test_get_frequency
# test_get_capacitance
# test_raise_error_on_unsupported_result_format
# test_ranging_mode
# test_set_sweep_auto_abort
# test_get_sweep_auto_abort
# test_set_post_sweep_voltage_cond
# test_get_post_sweep_voltage_cond
# test_cv_sweep_delay
# test_cmu_sweep_steps
# test_cv_sweep_voltages
# test_sweep_modes
# test_run_sweep
# test_phase_compensation_mode
# test_phase_compensation
# test_phase_compensation_with_mode
# test_enable_correction
# test_disable_correction
# test_correction_is_enabled
# test_correction_set_reference_values
# test_correction_get_reference_values
# test_clear_and_set_default_frequency_list_for_correction
# test_clear_frequency_list_for_correction
# test_add_frequency_for_correction
# test_query_from_frequency_list_for_correction
# test_query_at_index_from_frequency_list_for_correction
# test_perform_correction
# test_perform_and_enable_correction
# test_abort
# smu
# smu_output
# smu_sampling_measurement
# test_timing_parameters_is_none_at_init
# test_measurement_requires_timing_parameters_to_be_set
# test_sampling_measurement
# test_compliance_needs_data_from_sampling_measurement
# test_compliance
# test_output_data_type_and_data_channel
# test_same
# test_bad_dict
# test_key_diff
# test_val_diff_simple
# test_val_diff_seq
# test_nested_key_diff
# test_delegate_dict
# test_delegate_dicts
# test_delegate_object
# test_delegate_objects
# test_delegate_both
# test_python_types
# test_complex_types
# test_UFloat_type
# test_numpy_int_types
# test_numpy_float_types
# test_numpy_bool_type
# test_numpy_array
# test_non_serializable
# test_object_with_serialization_method
# SomeUserDict
# test_standard_encoder_fails_examplemetadata
# test_numpy_encoder_examplemetadata
# test_bytes
# test_bytes_array
# A
# BadKeysDict
# keys
# NoDelDict
# __delitem__
# test_normal
# test_pathological
# ones_generator
# simulated_alazar
# alazar_ctrl
# test_simulated_alazar
# snapshot_get
# snapshot_value
# get_cmd
# get_if_invalid
# update
# cache_is_valid
# _make_dummy_instrument
# GettableParam
# __init__
# get_raw
# BetterGettableParam
# __init__
# get_raw
# SettableParam
# __init__
# set_raw
# OverwriteGetParam
# __init__
# get
# OverwriteSetParam
# __init__
# set
# GetSetRawParameter
# __init__
# get_raw
# set_raw
# BookkeepingValidator
# __init__
# validate
# MemoryParameter
# __init__
# add_set_value
# create_get_func
# VirtualParameter
# __init__
# underlying_instrument
# get_raw
# ParameterMemory
# __init__
# get
# set
# set_p_prefixed
# parse_set_p
# strip_prefix
# SimpleArrayParam
# __init__
# get_raw
# SettableArray
# set_raw
# test_default_attributes
# test_explicit_attributes
# test_has_set_get
# test_full_name
# test_constructor_errors
# parameters
# test_combine
# test_sweep_bad_setpoints
# test_sweep
# test_set
# test_aggregator
# test_meta
# test_mutable
# test_arrays
# test_wrong_len
# test_invalid_name
# test_len
# linear
# _make_numeric_val
# _make_simple_param
# ObservableParam
# __init__
# set_raw
# get_raw
# get_instr_val
# make_observable_parameter
# test_observable_parameter
# test_observable_parameter_initial_value
# test_same_value
# test_same_label_and_unit_on_init
# test_overwritten_unit_on_init
# test_overwritten_label_on_init
# test_get_set_raises
# test_scaling
# test_scaling_delegate_initial_value
# test_scaling_initial_value
# test_snapshot
# test_set_source_cache_changes_delegate_cache
# test_set_source_cache_changes_delegate_get
# test_set_delegate_cache_changes_source_cache
# test_set_delegate_cache_with_raw_value
# test_instrument_val_invariant_under_delegate_cache_set
# test_delegate_cache_pristine_if_not_set
# test_delegate_get_updates_cache
# test_delegate_parameter_get_and_snapshot_with_none_source
# test_raw_value_scaling
# test_setting_initial_value_delegate_parameter
# test_setting_initial_cache_delegate_parameter
# test_delegate_parameter_with_none_source_works_as_expected
# test_delegate_parameter_with_changed_source_snapshot_matches_value
# _assert_none_source_is_correct
# _assert_delegate_cache_none_source
# test_gettable_settable_snapshotget_delegate_parameter
# test_gettable_settable_snapshotget_delegate_parameter_2
# test_initial_value_and_none_source_raises
# test_delegate_parameter_change_source_reflected_in_label_and_unit
# test_delegate_parameter_fixed_label_unit_unchanged
# test_cache_invalidation
# test_cache_no_source
# test_underlying_instrument_property_for_delegate_parameter
# test_value_validation
# test_value_validation_with_offset_and_scale
# test_elapsed_time_parameter_init
# test_elapsed_time_parameter_monotonic
# test_elapsed_time_parameter_reset_clock
# test_elapsed_time_parameter_not_settable
# test_elapsed_time_parameter_forbidden_kwargs
# test_get_latest
# test_get_latest_raw_value
# test_get_latest_unknown
# test_get_latest_known
# test_get_latest_no_get
# test_max_val_age
# test_no_get_max_val_age
# test_param_cmd_with_parsing
# test_parameter_with_overwritten_get_raises
# test_parameter_with_overwritten_set_raises
# test_gettable_settable_attributes_with_get_set_cmd
# test_gettable_settable_attributes_with_get_set_raw
# test_get_raw_and_get_cmd_raises
# test_get_on_parameter_marked_as_non_gettable_raises
# test_set_on_parameter_marked_as_non_settable_raises
# test_settable
# test_gettable
# close_all_instruments
# Dummy
# __init__
# write
# ask
# test_sanity
# test_raise_on_get_set_cmd
# test_raises_on_get_set_without_group
# test_raises_runtime_error_on_update_if_get_cmd_is_none
# test_raises_runtime_error_if_set_parameters_called_with_empty_dict
# test_set_parameters_called_for_one_parameter
# test_set_parameters_called_for_more_than_one_parameters
# test_set_parameters_when_parameter_value_not_equal_to_raw_value
# test_initial_values
# test_raise_on_not_all_initial_values
# test_update_group_parameter_reflected_in_cache_of_all_params
# test_get_group_param_updates_cache_of_other_param
# test_set_group_param_updates_cache_of_other_param
# test_group_param_scale_is_handled
# _make_instrument_a
# _make_instrument_d
# test_get_instr
# a_func
# AClass
# test_yes
# test_no
# test_open_file_is_not_sequence
# test_simple_good
# test_simple_bad
# test_examples_raises
# test_depth_good
# test_depth_bad
# test_shape_good
# test_shape_bad
# test_shape_depth
# test_good_calls
# test_bad_calls
# SimpleMultiParam
# __init__
# get_raw
# SettableMulti
# set_raw
# test_default_attributes
# test_explicit_attributes
# test_has_set_get
# test_full_name_s
# test_constructor_errors
# test_setting_non_gettable_parameter_with_finite_step
# test_values_of_mapping_are_only_the_given_two
# test_its_inverse_maps_only_to_booleans
# test_create_on_off_val_mapping_for
# test_no_name
# test_default_attributes
# test_explicit_attributes
# test_has_set_get
# test_str_representation
# test_bad_name
# test_set_via_function
# test_unknown_args_to_baseparameter_raises
# test_underlying_instrument_for_virtual_parameter
# test_get_cmd_str_no_instrument_raises
# test_set_cmd_str_no_instrument_raises
# test_get_from_cache_does_not_trigger_real_get_if_get_if_invalid_false
# test_initial_set_with_without_cache
# test_set_initial_and_initial_cache_raises
# test_get_cache
# test_get_cache_raw_value
# test_get_cache_unknown
# test_get_cache_known
# test_get_cache_no_get
# test_set_raw_value_on_cache
# test_max_val_age
# test_no_get_max_val_age
# test_no_get_max_val_age_runtime_error
# test_no_get_timestamp_none_runtime_error
# test_latest_dictionary_gets_updated_upon_set_of_memory_parameter
# test_set_latest_works_for_plain_memory_parameter
# test_get_from_cache_marked_invalid
# test_marking_invalid_via_instrument
# DummyTrackingInstrument
# __init__
# _vp_getter
# _vp_setter
# _pp_getter
# _pp_setter
# _cp_setter
# _cp_getter
# _make_instrument
# test_set_to_none_when_parameter_is_not_captured_yet
# test_set_to_none_for_not_captured_parameter_but_instrument_has_value
# test_none_value
# test_context
# test_validated_param
# test_parsed_param
# test_number_of_set_calls
# test_value_modified_between_context_create_and_enter
# test_disallow_changes
# test_allow_changes
# test_reset_at_exit
# test_reset_at_exit_with_allow_changes_false
# test_step_ramp
# test_ramp_scaled
# test_ramp_parser
# test_ramp_parsed_scaled
# test_stepping_from_invalid_starting_point
# BrokenParameter
# __init__
# BrokenParameter2
# __init__
# _make_dummy_attr_instr
# test_parameter_registration_on_instr
# test_parameter_registration_with_non_instr_passing_parameter
# test_parameter_registration_with_non_kwargs_passing_parameter
# test_scale_raw_value
# iterable_or_number
# test_scale_and_offset_raw_value_iterable
# test_scale_and_offset_raw_value_iterable_for_set_cache
# test_numpy_array_valued_parameter_preserves_type_if_scale_and_offset_are_set
# test_setting_numpy_array_valued_param_if_scale_and_offset_are_not_none
# test_number_of_validations
# test_number_of_validations_for_set_cache
# test_bad_validator
# test_setting_int_with_float
# test_setting_int_with_float_not_close
# parameters
# test_validation_shapes
# test_setpoints_non_parameter_raises
# test_validation_inconsistent_shape
# test_validation_wrong_validator
# test_validation_no_validator
# test_validation_sp_no_validator
# test_validation_without_shape
# test_validation_without_sp_shape
# test_validation_one_dim_missing
# test_validation_one_sp_dim_missing
# test_expand_setpoints_1c
# test_expand_setpoints_2d
# test_expand_setpoints_3d
# test_bad_calls
# test_good_calls
# _make_instrument
# test_constructor
# test_namelabel
# test_unit
# test_metadata
# test_wrapped_parameter
# test_divider
# test_multiplier
# test_variable_gain
# create_parameter
# test_snapshot_contains_parameter_attributes
# test_snapshot_timestamp_of_non_gettable_depends_only_on_cache_validity
# test_snapshot_timestamp_for_valid_cache_depends_on_cache_update
# test_snapshot_timestamp_for_invalid_cache_depends_only_on_snapshot_flags
# test_snapshot_when_snapshot_value_is_false
# test_snapshot_value_is_true_by_default
# test_snapshot_get_is_true_by_default
# test_snapshot_when_snapshot_get_is_false
# test_snapshot_of_non_gettable_parameter_mirrors_cache
# test_snapshot_of_gettable_parameter_depends_on_update
# test_snapshot_value
# _make_dummy_inst
# test_val_mapping_basic
# test_val_mapping_with_parsers
# test_on_off_val_mapping
# test_val_mapping_on_instrument
# DummyTestClass
# __init__
# DummyNoInitClass
# somefunction
# DummyDecoratedInitTestClass
# __init__
# DummyDecoratedClassTestClass
# __init__
# test_extract_class_attr
# test_extract_instance_attr
# test_instrument_base_get_attr
# test_visa_instr_get_attr
# test_decorated_init_func
# test_decorated_class
# test_no_init
# X
# test_attribute_set_to_value
# test_attribute_set_to_object
# test_full_class
# test_named_repr
# test_non_function
# test_function
# AClass
# method_a
# method_b
# method_c
# test_methods
# test_type_cast
# test_coroutine_check
# test_partial_with_docstring
# test_partial_with_docstring_pass_args
# test_partial_with_docstring_returns_value
# AClass
# method_a
# a_func
# test_type
# test_complex_min_max_raises
# test_complex
# test_complex_subtypes
# test_min_max_real_ints_raises
# test_min_max_ints_real_raises
# test_real_subtypes
# test_complex_default_raises
# test_text_type_raises
# test_text_array_raises
# test_default_types
# test_min_max
# test_max_smaller_min_raises
# test_shape
# test_shape_defered
# test_valid_values_with_shape
# test_valid_values
# test_shape_non_sequence_raises
# test_repr
# BrokenValidator
# __init__
# test_broken
# test_real_anything
# test_failed_anything
# test_bool
# test_valid_bool_values
# test_callable
# test_valid_values
# test_complex
# test_complex_raises
# test_dict
# test_valid_values
# test_good
# test_bad
# test_valid_values
# test_unlimited
# test_min
# test_min_raises
# test_max
# test_max_raises
# test_range
# test_failed_numbers
# test_valid_values
# test_type
# test_elt_vals
# test_valid_values
# test_divisors
# test_valid_values
# test_good_or
# test_good_and
# test_bad
# test_valid_values
# test_good
# test_bad
# test_good
# test_bad
# test_valid_values
# test_unlimited
# test_min
# test_min_raises
# test_max
# test_max_raises
# test_range
# test_failed_numbers
# test_valid_values
# test_close_to_ints
# test_bad_values
# test_valid_values
# test_passing
# test_not_passing
# test_precision
# test_valid_values
# test_type
# test_elt_vals
# test_valid_values
# test_length
# test_sorted
# test_unlimited
# test_min
# test_max
# test_range
# test_failed_strings
# test_valid_values

# %%
list(Path('./qcodes/tests').glob("**/*.py"))
# Out:
# [WindowsPath('qcodes/tests/common.py'),
#  WindowsPath('qcodes/tests/conftest.py'),
#  WindowsPath('qcodes/tests/dataset_generators.py'),
#  WindowsPath('qcodes/tests/driver_test_case.py'),
#  WindowsPath('qcodes/tests/instrument_mocks.py'),
#  WindowsPath('qcodes/tests/test_abstract_instrument.py'),
#  WindowsPath('qcodes/tests/test_autoloadable_channels.py'),
#  WindowsPath('qcodes/tests/test_channels.py'),
#  WindowsPath('qcodes/tests/test_command.py'),
#  WindowsPath('qcodes/tests/test_config.py'),
#  WindowsPath('qcodes/tests/test_deprecate.py'),
#  WindowsPath('qcodes/tests/test_field_vector.py'),
#  WindowsPath('qcodes/tests/test_installation_info.py'),
#  WindowsPath('qcodes/tests/test_instrument.py'),
#  WindowsPath('qcodes/tests/test_interactive_widget.py'),
#  WindowsPath('qcodes/tests/test_logger.py'),
#  WindowsPath('qcodes/tests/test_metadata.py'),
#  WindowsPath('qcodes/tests/test_monitor.py'),
#  WindowsPath('qcodes/tests/test_plot_utils.py'),
#  WindowsPath('qcodes/tests/test_snapshot.py'),
#  WindowsPath('qcodes/tests/test_station.py'),
#  WindowsPath('qcodes/tests/test_sweep_values.py'),
#  WindowsPath('qcodes/tests/test_testutils.py'),
#  WindowsPath('qcodes/tests/test_threading.py'),
#  WindowsPath('qcodes/tests/test_visa.py'),
#  WindowsPath('qcodes/tests/__init__.py'),
#  WindowsPath('qcodes/tests/dataset/conftest.py'),
#  WindowsPath('qcodes/tests/dataset/helper_functions.py'),
#  WindowsPath('qcodes/tests/dataset/test_concurrent_datasets.py'),
#  WindowsPath('qcodes/tests/dataset/test_converters.py'),
#  WindowsPath('qcodes/tests/dataset/test_database_creation_and_upgrading.py'),
#  WindowsPath('qcodes/tests/dataset/test_database_extract_runs.py'),
#  WindowsPath('qcodes/tests/dataset/test_datasaver.py'),
#  WindowsPath('qcodes/tests/dataset/test_dataset_basic.py'),
#  WindowsPath('qcodes/tests/dataset/test_dataset_export.py'),
#  WindowsPath('qcodes/tests/dataset/test_dataset_in_memory.py'),
#  WindowsPath('qcodes/tests/dataset/test_dataset_in_memory_bacis.py'),
#  WindowsPath('qcodes/tests/dataset/test_dataset_loading.py'),
#  WindowsPath('qcodes/tests/dataset/test_data_set_cache.py'),
#  WindowsPath('qcodes/tests/dataset/test_dependencies.py'),
#  WindowsPath('qcodes/tests/dataset/test_descriptions.py'),
#  WindowsPath('qcodes/tests/dataset/test_detect_shape.py'),
#  WindowsPath('qcodes/tests/dataset/test_experiment_container.py'),
#  WindowsPath('qcodes/tests/dataset/test_export_info.py'),
#  WindowsPath('qcodes/tests/dataset/test_fix_functions.py'),
#  WindowsPath('qcodes/tests/dataset/test_guids.py'),
#  WindowsPath('qcodes/tests/dataset/test_guid_helpers.py'),
#  WindowsPath('qcodes/tests/dataset/test_links.py'),
#  WindowsPath('qcodes/tests/dataset/test_metadata.py'),
#  WindowsPath('qcodes/tests/dataset/test_nested_measurements.py'),
#  WindowsPath('qcodes/tests/dataset/test_paramspec.py'),
#  WindowsPath('qcodes/tests/dataset/test_plotting.py'),
#  WindowsPath('qcodes/tests/dataset/test_snapshot.py'),
#  WindowsPath('qcodes/tests/dataset/test_sqlitesettings.py'),
#  WindowsPath('qcodes/tests/dataset/test_sqlite_base.py'),
#  WindowsPath('qcodes/tests/dataset/test_sqlite_connection.py'),
#  WindowsPath('qcodes/tests/dataset/test_string_data.py'),
#  WindowsPath('qcodes/tests/dataset/test_subscribing.py'),
#  WindowsPath('qcodes/tests/dataset/test__get_data_from_ds.py'),
#  WindowsPath('qcodes/tests/dataset/__init__.py'),
#  WindowsPath('qcodes/tests/dataset/dond/conftest.py'),
#  WindowsPath('qcodes/tests/dataset/dond/test_do0d.py'),
#  WindowsPath('qcodes/tests/dataset/dond/test_do1d.py'),
#  WindowsPath('qcodes/tests/dataset/dond/test_do2d.py'),
#  WindowsPath('qcodes/tests/dataset/dond/test_doNd.py'),
#  WindowsPath('qcodes/tests/dataset/dond/__init__.py'),
#  WindowsPath('qcodes/tests/dataset/fixtures/__init__.py'),
#  WindowsPath('qcodes/tests/dataset/fixtures/data_2018_01_17/__init__.py'),
#  WindowsPath('qcodes/tests/dataset/fixtures/data_2018_01_17/data_001_testsweep_15_42_57/__init__.py'),
#  WindowsPath('qcodes/tests/dataset/fixtures/data_2018_01_17/data_002_2D_test_15_43_14/__init__.py'),
#  WindowsPath('qcodes/tests/dataset/measurement/test_load_legacy_data.py'),
#  WindowsPath('qcodes/tests/dataset/measurement/test_measurement_context_manager.py'),
#  WindowsPath('qcodes/tests/dataset/measurement/test_shapes.py'),
#  WindowsPath('qcodes/tests/dataset/measurement/__init__.py'),
#  WindowsPath('qcodes/tests/delegate/conftest.py'),
#  WindowsPath('qcodes/tests/delegate/test_delegate_instrument.py'),
#  WindowsPath('qcodes/tests/delegate/test_device.py'),
#  WindowsPath('qcodes/tests/delegate/__init__.py'),
#  WindowsPath('qcodes/tests/delegate/data/__init__.py'),
#  WindowsPath('qcodes/tests/drivers/test_Agilent_E8257D.py'),
#  WindowsPath('qcodes/tests/drivers/test_AimTTi_PL601P.py'),
#  WindowsPath('qcodes/tests/drivers/test_ami430.py'),
#  WindowsPath('qcodes/tests/drivers/test_ami430_visa.py'),
#  WindowsPath('qcodes/tests/drivers/test_Keithley_2450.py'),
#  WindowsPath('qcodes/tests/drivers/test_keithley_26xx.py'),
#  WindowsPath('qcodes/tests/drivers/test_keithley_3706A.py'),
#  WindowsPath('qcodes/tests/drivers/test_keithley_7510.py'),
#  WindowsPath('qcodes/tests/drivers/test_keithley_s46.py'),
#  WindowsPath('qcodes/tests/drivers/test_Keysight_33XXX.py'),
#  WindowsPath('qcodes/tests/drivers/test_keysight_34465a.py'),
#  WindowsPath('qcodes/tests/drivers/test_keysight_34934a.py'),
#  WindowsPath('qcodes/tests/drivers/test_keysight_34980a.py'),
#  WindowsPath('qcodes/tests/drivers/test_keysight_b220x.py'),
#  WindowsPath('qcodes/tests/drivers/test_keysight_e4980a.py'),
#  WindowsPath('qcodes/tests/drivers/test_Keysight_N6705B.py'),
#  WindowsPath('qcodes/tests/drivers/test_keysight_n9030b.py'),
#  WindowsPath('qcodes/tests/drivers/test_lakeshore.py'),
#  WindowsPath('qcodes/tests/drivers/test_lakeshore_325.py'),
#  WindowsPath('qcodes/tests/drivers/test_lakeshore_325_legacy.py'),
#  WindowsPath('qcodes/tests/drivers/test_lakeshore_336.py'),
#  WindowsPath('qcodes/tests/drivers/test_lakeshore_336_legacy.py'),
#  WindowsPath('qcodes/tests/drivers/test_lakeshore_file_parser.py'),
#  WindowsPath('qcodes/tests/drivers/test_MercuryiPS.py'),
#  WindowsPath('qcodes/tests/drivers/test_Rigol_DS1074Z.py'),
#  WindowsPath('qcodes/tests/drivers/test_rto_1000.py'),
#  WindowsPath('qcodes/tests/drivers/test_stahl.py'),
#  WindowsPath('qcodes/tests/drivers/test_tektronix_AWG5014C.py'),
#  WindowsPath('qcodes/tests/drivers/test_tektronix_AWG5208.py'),
#  WindowsPath('qcodes/tests/drivers/test_tektronix_AWG70000A.py'),
#  WindowsPath('qcodes/tests/drivers/test_tektronix_dpo7200xx.py'),
#  WindowsPath('qcodes/tests/drivers/test_weinchel.py'),
#  WindowsPath('qcodes/tests/drivers/test_yokogawa_gs200.py'),
#  WindowsPath('qcodes/tests/drivers/__init__.py'),
#  WindowsPath('qcodes/tests/drivers/AlazarTech/test_alazar_api.py'),
#  WindowsPath('qcodes/tests/drivers/AlazarTech/test_alazar_buffer.py'),
#  WindowsPath('qcodes/tests/drivers/AlazarTech/test_dll_wrapper.py'),
#  WindowsPath('qcodes/tests/drivers/AlazarTech/__init__.py'),
#  WindowsPath('qcodes/tests/drivers/auxiliary_files/__init__.py'),
#  WindowsPath('qcodes/tests/drivers/keysight_b1500/test_commandList.py'),
#  WindowsPath('qcodes/tests/drivers/keysight_b1500/test_MessageBuilder.py'),
#  WindowsPath('qcodes/tests/drivers/keysight_b1500/__init__.py'),
#  WindowsPath('qcodes/tests/drivers/keysight_b1500/b1500_driver_tests/conftest.py'),
#  WindowsPath('qcodes/tests/drivers/keysight_b1500/b1500_driver_tests/test_b1500.py'),
#  WindowsPath('qcodes/tests/drivers/keysight_b1500/b1500_driver_tests/test_b1500_module.py'),
#  WindowsPath('qcodes/tests/drivers/keysight_b1500/b1500_driver_tests/test_b1511b_smu.py'),
#  WindowsPath('qcodes/tests/drivers/keysight_b1500/b1500_driver_tests/test_b1517a_smu.py'),
#  WindowsPath('qcodes/tests/drivers/keysight_b1500/b1500_driver_tests/test_b1520a_cmu.py'),
#  WindowsPath('qcodes/tests/drivers/keysight_b1500/b1500_driver_tests/test_sampling_measurement.py'),
#  WindowsPath('qcodes/tests/drivers/keysight_b1500/b1500_driver_tests/__init__.py'),
#  WindowsPath('qcodes/tests/helpers/test_compare_dictionaries.py'),
#  WindowsPath('qcodes/tests/helpers/test_delegate_attribues.py'),
#  WindowsPath('qcodes/tests/helpers/test_json_encoder.py'),
#  WindowsPath('qcodes/tests/helpers/test_strip_attrs.py'),
#  WindowsPath('qcodes/tests/helpers/__init__.py'),
#  WindowsPath('qcodes/tests/mockers/test_simulated_ats_api.py'),
#  WindowsPath('qcodes/tests/mockers/__init__.py'),
#  WindowsPath('qcodes/tests/parameter/conftest.py'),
#  WindowsPath('qcodes/tests/parameter/test_array_parameter.py'),
#  WindowsPath('qcodes/tests/parameter/test_combined_par.py'),
#  WindowsPath('qcodes/tests/parameter/test_delegate_parameter.py'),
#  WindowsPath('qcodes/tests/parameter/test_elapsed_time_parameter.py'),
#  WindowsPath('qcodes/tests/parameter/test_get_latest.py'),
#  WindowsPath('qcodes/tests/parameter/test_get_set_parser.py'),
#  WindowsPath('qcodes/tests/parameter/test_get_set_wrapping.py'),
#  WindowsPath('qcodes/tests/parameter/test_group_parameter.py'),
#  WindowsPath('qcodes/tests/parameter/test_instrument_ref_parameter.py'),
#  WindowsPath('qcodes/tests/parameter/test_issequence.py'),
#  WindowsPath('qcodes/tests/parameter/test_issequenceof.py'),
#  WindowsPath('qcodes/tests/parameter/test_make_sweep.py'),
#  WindowsPath('qcodes/tests/parameter/test_multi_parameter.py'),
#  WindowsPath('qcodes/tests/parameter/test_non_gettable_parameter.py'),
#  WindowsPath('qcodes/tests/parameter/test_on_off_mapping.py'),
#  WindowsPath('qcodes/tests/parameter/test_parameter_basics.py'),
#  WindowsPath('qcodes/tests/parameter/test_parameter_cache.py'),
#  WindowsPath('qcodes/tests/parameter/test_parameter_context_manager.py'),
#  WindowsPath('qcodes/tests/parameter/test_parameter_ramp.py'),
#  WindowsPath('qcodes/tests/parameter/test_parameter_registration.py'),
#  WindowsPath('qcodes/tests/parameter/test_parameter_scale_offset.py'),
#  WindowsPath('qcodes/tests/parameter/test_parameter_validation.py'),
#  WindowsPath('qcodes/tests/parameter/test_parameter_with_setpoints.py'),
#  WindowsPath('qcodes/tests/parameter/test_permissive_range.py'),
#  WindowsPath('qcodes/tests/parameter/test_scaled_parameter.py'),
#  WindowsPath('qcodes/tests/parameter/test_snapshot.py'),
#  WindowsPath('qcodes/tests/parameter/test_val_mapping.py'),
#  WindowsPath('qcodes/tests/parameter/__init__.py'),
#  WindowsPath('qcodes/tests/sphinx_extension/test_parse_parameter_attr.py'),
#  WindowsPath('qcodes/tests/sphinx_extension/__init__.py'),
#  WindowsPath('qcodes/tests/utils/test_attributes_set_to_context_manager.py'),
#  WindowsPath('qcodes/tests/utils/test_class_strings.py'),
#  WindowsPath('qcodes/tests/utils/test_isfunction.py'),
#  WindowsPath('qcodes/tests/utils/test_partial_with_docstring.py'),
#  WindowsPath('qcodes/tests/utils/__init__.py'),
#  WindowsPath('qcodes/tests/validators/conftest.py'),
#  WindowsPath('qcodes/tests/validators/test_arrays.py'),
#  WindowsPath('qcodes/tests/validators/test_basic.py'),
#  WindowsPath('qcodes/tests/validators/test_bool.py'),
#  WindowsPath('qcodes/tests/validators/test_callable.py'),
#  WindowsPath('qcodes/tests/validators/test_complex.py'),
#  WindowsPath('qcodes/tests/validators/test_dict.py'),
#  WindowsPath('qcodes/tests/validators/test_enum.py'),
#  WindowsPath('qcodes/tests/validators/test_ints.py'),
#  WindowsPath('qcodes/tests/validators/test_lists.py'),
#  WindowsPath('qcodes/tests/validators/test_multiples.py'),
#  WindowsPath('qcodes/tests/validators/test_multi_type.py'),
#  WindowsPath('qcodes/tests/validators/test_multi_type_and.py'),
#  WindowsPath('qcodes/tests/validators/test_multi_type_or.py'),
#  WindowsPath('qcodes/tests/validators/test_numbers.py'),
#  WindowsPath('qcodes/tests/validators/test_permissive_ints.py'),
#  WindowsPath('qcodes/tests/validators/test_permissive_multiples.py'),
#  WindowsPath('qcodes/tests/validators/test_sequence.py'),
#  WindowsPath('qcodes/tests/validators/test_string.py'),
#  WindowsPath('qcodes/tests/validators/__init__.py')]
